# %% [markdown]
# ### LINEAR REGRESSION CASE STUDY
#   BUISNESS PROBLEM DEFINTION - one of the major automoblie company would like to design new product which can improve the sales .In order to define the product,they understanding / identify drivers for the sales ( what are the factors driving sales) and PREDICTION SALES OF DIFFERENT CAR MODELS

# %% [markdown]
# ## IMPORT NECESSARY Libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %matplotlib inline
import statsmodels.formula.api as smf
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score , mean_squared_error , mean_absolute_error

# %% [markdown]
# ## IMPORT DATASET

# %%
cars = pd.read_csv('automobile_data.csv1.csv')

# %% [markdown]
# ### General Information About to Dataset

# %%
cars.head()
# Out:
#    manufacture fuel_type   body_style  wheelbase  length  width  curb-weight  \
# 0  alfa-romero       gas  convertible       88.6   168.8   64.1       2548.0
# 1  alfa-romero       gas  convertible       88.6   168.8   64.1       2548.0
# 2  alfa-romero       gas    hatchback       94.5   171.2   65.5       2823.0
# 3         audi       gas        sedan       99.8   176.6   66.2       2337.0
# 4         audi       gas        sedan       99.4   176.6   66.4       2824.0
#
#   horsepower  engine_size  price_in_thousands  sales_in_thousands
# 0        111        130.0                25.0                65.0
# 1        111        130.0                44.0                41.0
# 2        154        152.0                48.0                25.0
# 3        102        109.0                28.0                36.0
# 4        115        136.0                36.0                62.0

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   manufacture         205 non-null    object
#  1   fuel_type           205 non-null    object
#  2   body_style          205 non-null    object
#  3   wheelbase           205 non-null    float64
#  4   length              205 non-null    float64
#  5   width               205 non-null    float64
#  6   curb-weight         205 non-null    float64
#  7   horsepower          205 non-null    object
#  8   engine_size         205 non-null    float64
#  9   price_in_thousands  205 non-null    float64
#  10  sales_in_thousands  205 non-null    float64
# dtypes: float64(7), object(4)
# memory usage: 17.9+ KB

# %%
cars.shape
# Out:
# (207, 11)

# %%
cars.rename( columns = {'Fuel - type': 'fuel_type', 'body-style':'body_style', 'wheel-base' : 'wheelbase' , 'engine size':'engine_size'} , inplace = True)

# %%
# no of unique value / cardinality
cars.nunique()
# Out:
# manufacture            22
# fuel_type               2
# body_style              5
# wheelbase              53
# length                 75
# width                  44
# curb-weight           171
# horsepower             60
# engine_size            44
# price_in_thousands     34
# sales_in_thousands     41
# dtype: int64

# %%
# in case we have huge data and we don't make the copy of the original data 
# we generally go with the option of getting columns/ varibale name for object and numeric type
# seperate categorical(object) and continuous(numeric variables)
numeric_columns = cars.select_dtypes( include = [ 'float64', 'int16'])
object_columns = cars.select_dtypes( include = [ 'object']).columns

# %%
cars[object_columns].head()
# Out:
#    manufacture fuel_type   body_style horsepower
# 0  alfa-romero       gas  convertible        111
# 1  alfa-romero       gas  convertible        111
# 2  alfa-romero       gas    hatchback        154
# 3         audi       gas        sedan        102
# 4         audi       gas        sedan        115

# %%
cars[numeric_columns].head()
# Out:
#    wheelbase  length  width  curb-weight  engine_size  price_in_thousands  \
# 0       88.6   168.8   64.1       2548.0        130.0                25.0
# 1       88.6   168.8   64.1       2548.0        130.0                44.0
# 2       94.5   171.2   65.5       2823.0        152.0                48.0
# 3       99.8   176.6   66.2       2337.0        109.0                28.0
# 4       99.4   176.6   66.4       2824.0        136.0                36.0
#
#    sales_in_thousands
# 0                65.0
# 1                41.0
# 2                25.0
# 3                36.0
# 4                62.0

# %%
## alternate describe() for continuous variable
def continous_var_summary (x):
    n_tot = x.shape[0]
    nmiss = x.isna().sum()
    nmiss_perc = nmiss * 100 / n_tot
    # for outliers
    q1 = x.quantile(0.25)
    q3 = x.quantile( 0.75)
    iqr= q3 - q1
    lc_iqr = q1 - 1.5 * iqr
    uc_iqr = q3 - 1.5 * iqr
    return pd.Series( [ x.dtypes, x.nunique(), n_tot, x.count(), nmiss, nmiss_perc, x.mean(), x.std(), x.var(), lc_iqr, uc_iqr, x.min(),
                       x.quantile(0.01), x.quantile(0.05), x.quantile(0.1), x.quantile(0.25), x.quantile(0.5), x.quantile(0.75), x.quantile(0.90),
                       x.quantile(0.95), x.quantile(0.99), x.max()],
    index = [ 'dtype', 'cardinality', 'n_tot', ' n', ' nmiss', 'nmiss_perc', 'mean', 'std', 'var', 'lc_iqr', 'uc_iqr', 'min', 
             'p1', 'p5', 'p10', 'p25', 'p50', 'p75', 'p90', 'p95', 'p99', 'max'])

# %%
numeric_columns.apply(continous_var_summary)
# Out:
#              wheelbase      length      width    curb-weight  engine_size  \
# dtype          float64     float64    float64        float64      float64
# cardinality         53          75         44            171           44
# n_tot              207         207        207            207          207
#  n                 205         205        205            205          205
#  nmiss               2           2          2              2            2
# nmiss_perc    0.966184    0.966184   0.966184       0.966184     0.966184
# mean         98.756585  174.049268  65.907805    2555.565854   126.907317
# std           6.021776   12.337289   2.145204     520.680204    41.642693
# var          36.261782  152.208688     4.6019  271107.874319  1734.113917
# lc_iqr           82.65       141.1       59.9          960.0         31.0
# uc_iqr           90.55       157.9       62.7         1750.0         75.0
# min               86.6       141.1       60.3         1488.0         61.0
# p1              88.408     144.816     62.536        1819.72         70.0
# p5               93.02      157.14       63.6         1901.0         90.0
# p10               93.7       157.3       63.8         1947.0         91.0
# p25               94.5       166.3       64.1         2145.0         97.0
# p50               97.0       173.2       65.5         2414.0        120.0
# p75              102.4       183.1       66.9         2935.0        141.0
# p90              107.9       188.8      68.64         3230.0        181.0
# p95              110.0      196.36      70.46         3503.0        201.2
# p99            115.544      202.48       71.7         3948.0       302.16
# max              120.9       208.1       72.3         4066.0        326.0
#
#             price_in_thousands sales_in_thousands
# dtype                  float64            float64
# cardinality                 34                 41
# n_tot                      207                207
#  n                         205                205
#  nmiss                       2                  2
# nmiss_perc            0.966184           0.966184
# mean                 33.834146          45.780488
# std                   9.719185          12.044672
# var                  94.462554         145.074127
# lc_iqr                     2.0                2.5
# uc_iqr                    18.0               23.5
# min                       17.0               25.0
# p1                        18.0               25.0
# p5                        19.0               27.0
# p10                       20.4               29.0
# p25                       26.0               34.0
# p50                       34.0               48.0
# p75                       42.0               55.0
# p90                       48.0               62.0
# p95                       49.0               64.0
# p99                       50.0               65.0
# max                       50.0               65.0

# %% [markdown]
# ## treatment the outliers

# %%
numeric_columns = numeric_columns.apply(lambda x : x.clip( lower = x.quantile(0.01) , upper = x.quantile(0.99)))

# %% [markdown]
# ## there is no missing value under this ,so missing imputation will not required
# ## for season , we can't simply leave the enconding as 1 = spring ,2 = summer , 3 = fall because that would imply an ordered relationship . Instead , we create dummiess

# %%
cars.manufacture.nunique()
# Out:
# 22

# %%
pd.get_dummies(cars.manufacture , prefix = 'manufacture' , drop_first = True )
# Out:
#      manufacture_audi  manufacture_bmw  manufacture_chevrolet  \
# 0               False            False                  False
# 1               False            False                  False
# 2               False            False                  False
# 3                True            False                  False
# 4                True            False                  False
# ..                ...              ...                    ...
# 202             False            False                  False
# 203             False            False                  False
# 204             False            False                  False
# 205             False            False                  False
# 206             False            False                  False
#
#      manufacture_dodge  manufacture_honda  manufacture_isuzu  \
# 0                False              False              False
# 1                False              False              False
# 2                False              False              False
# 3                False              False              False
# 4                False              False              False
# ..                 ...                ...                ...
# 202              False              False              False
# 203              False              False              False
# 204              False              False              False
# 205              False              False              False
# 206              False              False              False
#
#      manufacture_jaguar  manufacture_mazda  manufacture_mercedes-benz  \
# 0                 False              False                      False
# 1                 False              False                      False
# 2                 False              False                      False
# 3                 False              False                      False
# 4                 False              False                      False
# ..                  ...                ...                        ...
# 202               False              False                      False
# 203               False              False                      False
# 204               False              False                      False
# 205               False              False                      False
# 206               False              False                      False
#
#      manufacture_mercury  ...  manufacture_nissan  manufacture_peugot  \
# 0                  False  ...               False               False
# 1                  False  ...               False               False
# 2                  False  ...               False               False
# 3                  False  ...               False               False
# 4                  False  ...               False               False
# ..                   ...  ...                 ...                 ...
# 202                False  ...               False               False
# 203                False  ...               False               False
# 204                False  ...               False               False
# 205                False  ...               False               False
# 206                False  ...               False               False
#
#      manufacture_plymouth  manufacture_porsche  manufacture_renault  \
# 0                   False                False                False
# 1                   False                False                False
# 2                   False                False                False
# 3                   False                False                False
# 4                   False                False                False
# ..                    ...                  ...                  ...
# 202                 False                False                False
# 203                 False                False                False
# 204                 False                False                False
# 205                 False                False                False
# 206                 False                False                False
#
#      manufacture_saab  manufacture_subaru  manufacture_toyota  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
# ..                ...                 ...                 ...
# 202             False               False               False
# 203             False               False               False
# 204             False               False               False
# 205             False               False               False
# 206             False               False               False
#
#      manufacture_volkswagen  manufacture_volvo
# 0                     False              False
# 1                     False              False
# 2                     False              False
# 3                     False              False
# 4                     False              False
# ..                      ...                ...
# 202                   False               True
# 203                   False               True
# 204                   False               True
# 205                   False              False
# 206                   False              False
#
# [207 rows x 21 columns]

# %%
## get the count of all categories of the variables
cars.manufacture.value_counts()
# Out:
# manufacture
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# mercury           1
# Name: count, dtype: int64

# %% [markdown]
# ## in case we have categorical feature as numeric type , we have to first convert into category type

# %%
# get the useful variable categorical variables
object_columns = cars.loc[:, ['manufacture','body_style']]

for var in object_columns.columns:
    df_temp = pd.get_dummies(object_columns[var], prefix = var,drop_first = True)
    object_columns = pd.concat([object_columns, df_temp], axis = 1)
    object_columns.drop(columns = var , inplace = True)

# %% [markdown]
# ## All the variables should follow the INC rules going further

# %%
object_columns.columns
# Out:
# Index(['manufacture_audi', 'manufacture_bmw', 'manufacture_chevrolet',
#        'manufacture_dodge', 'manufacture_honda', 'manufacture_isuzu',
#        'manufacture_jaguar', 'manufacture_mazda', 'manufacture_mercedes-benz',
#        'manufacture_mercury', 'manufacture_mitsubishi', 'manufacture_nissan',
#        'manufacture_peugot', 'manufacture_plymouth', 'manufacture_porsche',
#        'manufacture_renault', 'manufacture_saab', 'manufacture_subaru',
#        'manufacture_toyota', 'manufacture_volkswagen', 'manufacture_volvo',
#        'body_style_hardtop', 'body_style_hatchback', 'body_style_sedan',
#        'body_style_wagon'],
#       dtype='object')

# %% [markdown]
# ## combine the date ( categorical and continuous variable)

# %%
car_new = pd.concat([numeric_columns , object_columns] , axis = 1)

# %%
car_new.shape
# Out:
# (207, 32)

# %% [markdown]
# ## assumption check - all the variables follow the normal distribution

# %%
sns.distplot(car_new.sales_in_thousands)
plt.show()
## this distribution is highly skewed
# Out:
# C:\Users\Ritik\AppData\Local\Temp\ipykernel_21876\3501389955.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(car_new.sales_in_thousands)
# C:\Users\Ritik\anaconda4\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
car_new.sales_in_thousands.skew()
# Out:
# -0.10293716105954594

# %%
corrm =car_new.corr()
plt.figure (figsize = (13,8))
sns.heatmap(car_new.corr())
# Out:
# <Axes: >

# %% [markdown]
# ## split the data for modelling

# %%
## divide the data into training and testing 
train, test = train_test_split(car_new, test_size = 0.3 , random_state = 12345)

# %%
train.shape
# Out:
# (144, 32)

# %%
test.shape
# Out:
# (63, 32)

# %% [markdown]
# # building a linear regression model

# %%
m1_equation = '''sales_in_thousands~ manufacture_bmw + price_in_thousands + length + wheelbase  '''

# %%
lm0 =smf.ols(m1_equation , train ).fit()

# %%
print(lm0.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     sales_in_thousands   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     1.126
# Date:                Sat, 15 Jun 2024   Prob (F-statistic):              0.347
# Time:                        16:20:42   Log-Likelihood:                -552.86
# No. Observations:                 142   AIC:                             1116.
# Df Residuals:                     137   BIC:                             1131.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  65.0727     18.084      3.598      0.000      29.313     100.833
# manufacture_bmw[T.True]    -3.0701      6.170     -0.498      0.620     -15.272       9.131
# price_in_thousands         -0.1045      0.106     -0.989      0.324      -0.314       0.104
# length                      0.2558      0.173      1.481      0.141      -0.086       0.597
# wheelbase                  -0.6067      0.349     -1.739      0.084      -1.297       0.083
# ==============================================================================
# Omnibus:                       43.945   Durbin-Watson:                   1.876
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                7.953
# Skew:                          -0.077   Prob(JB):                       0.0187
# Kurtosis:                       1.851   Cond. No.                     3.62e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.62e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
## Due to strong multicollinearity the prediction is failed , we need to figure more accuarte x variables to analayis this model
